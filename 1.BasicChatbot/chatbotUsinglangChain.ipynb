# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(
    model="llama3.2",
    temperature=0
)

# %%
response = llm.invoke("What is LangChain?")

print(response.content)
# Out:
# LangChain is an open-source, Python-based framework for building blockchain-agnostic data pipelines. It allows developers to create scalable and flexible data processing workflows that can be used across multiple blockchain platforms.
#
# LangChain provides a set of tools and libraries that enable the creation of data pipelines, including:
#
# 1. Data ingestion: LangChain provides APIs for ingesting data from various sources, such as blockchains, databases, and file systems.
# 2. Data transformation: The framework offers a range of data transformation functions, allowing developers to manipulate and process data in various formats.
# 3. Data storage: LangChain supports multiple data storage options, including blockchain-based storage solutions like IPFS (InterPlanetary File System) and external databases.
#
# LangChain's primary goal is to enable the creation of decentralized data pipelines that can be used across different blockchain platforms, such as Ethereum, Solana, and Polkadot. By providing a standardized framework for building data pipelines, LangChain aims to simplify the process of integrating blockchain-based applications with traditional data processing workflows.
#
# Some key features of LangChain include:
#
# * Blockchain-agnostic: LangChain supports multiple blockchain platforms, allowing developers to build data pipelines that can be used across different ecosystems.
# * Scalable: The framework is designed to handle large volumes of data and scale horizontally to meet the needs of complex data processing workflows.
# * Flexible: LangChain provides a range of tools and libraries that enable developers to customize their data pipelines to suit specific use cases.
#
# Overall, LangChain is an innovative framework that enables the creation of decentralized data pipelines, providing a standardized solution for building blockchain-agnostic data workflows.

# %%
#Now add LangChain messages

from langchain_core.messages import HumanMessage

message = HumanMessage(
    content="What is LangGraph?"
)

response = llm.invoke([message])

print(response.content)
# Out:
# LangGraph is an open-source, graph-based data structure and algorithm library for Rust programming language. It provides a simple and efficient way to work with graphs in Rust.
#
# LangGraph allows you to create, manipulate, and query graphs using a variety of data structures such as adjacency lists, edge lists, and adjacency matrices. It also provides various algorithms for graph traversal, shortest paths, and graph optimization.
#
# Some key features of LangGraph include:
#
# 1. Efficient graph representation: LangGraph uses an efficient in-memory representation of graphs, making it suitable for large-scale graph processing.
# 2. Simple API: The library has a simple and intuitive API that makes it easy to work with graphs.
# 3. Support for various graph algorithms: LangGraph provides implementations of popular graph algorithms such as Dijkstra's algorithm, Bellman-Ford algorithm, and Floyd-Warshall algorithm.
# 4. Support for graph optimization: LangGraph also provides tools for optimizing graphs, such as removing redundant edges and nodes.
#
# LangGraph is designed to be used in a variety of applications, including:
#
# 1. Network analysis
# 2. Social network analysis
# 3. Recommendation systems
# 4. Traffic routing
# 5. Machine learning
#
# Overall, LangGraph is a powerful tool for working with graphs in Rust, providing an efficient and easy-to-use API for graph manipulation and optimization.

# %%
from langchain_core.messages import HumanMessage, AIMessage

messages = []

messages.append(
    HumanMessage(content="My name is Bensly.")
)

response = llm.invoke(messages)

messages.append(response)

print(response.content)
# Out:
# Hello Bensly! It's nice to meet you. Is there something I can help you with or would you like to chat?

# %%
messages
# Out:
# [HumanMessage(content='My name is Bensly.', additional_kwargs={}, response_metadata={}),
#  AIMessage(content="Hello Bensly! It's nice to meet you. Is there something I can help you with or would you like to chat?", additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-08-13T06:41:45.1061525Z', 'done': True, 'done_reason': 'stop', 'total_duration': 20162794300, 'load_duration': 15159519300, 'prompt_eval_count': 32, 'prompt_eval_duration': 1150938000, 'eval_count': 28, 'eval_duration': 3811714000, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--019ff9da-a9ba-7653-b666-6998161de8ff-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 32, 'output_tokens': 28, 'total_tokens': 60})]

# %%
messages.append(
    HumanMessage(content="What is my name?")
)

response = llm.invoke(messages)

messages.append(response)

print(response.content)
# Out:
# Your name is Bensly. You told me that earlier.

# %%
messages
# Out:
# [HumanMessage(content='My name is Bensly.', additional_kwargs={}, response_metadata={}),
#  AIMessage(content="Hello Bensly! It's nice to meet you. Is there something I can help you with or would you like to chat?", additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-08-13T06:41:45.1061525Z', 'done': True, 'done_reason': 'stop', 'total_duration': 20162794300, 'load_duration': 15159519300, 'prompt_eval_count': 32, 'prompt_eval_duration': 1150938000, 'eval_count': 28, 'eval_duration': 3811714000, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--019ff9da-a9ba-7653-b666-6998161de8ff-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 32, 'output_tokens': 28, 'total_tokens': 60}),
#  HumanMessage(content='What is my name?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='Your name is Bensly. You told me that earlier.', additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-08-13T06:43:05.8341199Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4167621500, 'load_duration': 983289100, 'prompt_eval_count': 74, 'prompt_eval_duration': 1009143000, 'eval_count': 14, 'eval_duration': 2137054000, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--019ff9dc-2387-7640-a4f1-48bd8ad5b4d7-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 74, 'output_tokens': 14, 'total_tokens': 88})]
