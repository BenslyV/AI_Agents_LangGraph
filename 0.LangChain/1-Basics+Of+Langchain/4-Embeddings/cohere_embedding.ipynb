# %%
import os
from dotenv import load_dotenv
load_dotenv()  #load all the environment variables
# Out:
# True

# %%
os.environ['COHERE_API_KEY']=os.getenv("COHERE_API_KEY")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 os.environ['COHERE_API_KEY']=os.getenv("COHERE_API_KEY")
#
# File <frozen os>:722, in __setitem__(self, key, value)
#
# File <frozen os>:782, in check_str(value)
#
# TypeError: str expected, not NoneType

# %%
from langchain_cohere import CohereEmbeddings

# Initialize embeddings
embeddings = CohereEmbeddings(model="embed-english-v3.0")

# Example query
text = "This is a tutorial on Cohere embeddings"
vector = embeddings.embed_query(text)

print(len(vector))   # vector length (usually 1024)
print(vector[:10])   # preview first 10 values
